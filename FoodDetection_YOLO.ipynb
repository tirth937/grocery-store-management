# %% [markdown]
# # Food Detection using YOLOv11
#
# This notebook has been modernized to use **YOLOv11** (via the `ultralytics` library). The legacy TensorFlow 1.x workflow is no longer compatible with modern Python environments.

# %% [markdown]
# ### Step 1: Convert Annotations
# First, we convert the existing XML annotations (Pascal VOC) into the YOLO format. This will also create a `data.yaml` file needed for training.

# %%
# !python convert_to_yolo.py

# %% [markdown]
# ### Step 2: Train the Model
# We use the converted dataset to train a YOLOv11 nano model. This model is fast and efficient for CPU/GPU training.

# %%
# !python train_yolo.py

# %% [markdown]
# ### Step 3: Run Inference
# After training, we can run detection on our test images to see the results.

# %%
# !python detect_food.py
